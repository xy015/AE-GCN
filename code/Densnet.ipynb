# %%
import os, time, copy
from glob import glob
import numpy as np
import pandas as pd
from tqdm import tqdm, trange
from random import seed, shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from skimage.color import gray2rgb
import matplotlib.pyplot as plt
from utils.myutils import *

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 设置TensorFlow的日志级别为2，只显示error和warining信息

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.get_logger().setLevel('ERROR') #删除多余的日志

import  tensorflow as tf
from    tensorflow import keras
from    tensorflow.keras import layers, models, Sequential
from keras.optimizers import adam_v2

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten,Reshape, Dropout, BatchNormalization, Activation, AveragePooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import GlobalMaxPool2D, Concatenate
from tensorflow.keras import Model,optimizers

from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping
# Out:
# WARNING:tensorflow:From /root/miniconda3/envs/myconda/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
data_path = "./data/slices60/"  # 数据路径
model_path = "./model/VGG16/"  # 设置模型保存目录
# 创建目录
for path in [model_path]:
    print(path)
    if not os.path.exists(path):
        os.makedirs(path)
# Out:
# ./model/VGG16/

# %% [markdown]
# # 1.数据预处理

# %%
# 数据
imagePaths = glob(data_path + "*/*flag_*.npy")  # 两个目录下的所有结节文件
imagePaths = np.asarray(imagePaths)  # 转numpy
print(imagePaths[:5])
print(f"共有{len(imagePaths)}个npy文件")
# 标签
labels = [x.split("flag_")[1].split(".npy")[0] for x in imagePaths]  # 提取各文件对应的标签
# print(labels[:5])
le = LabelEncoder()  # 标签编码器
labels = le.fit_transform(labels)  # 处理标签，标签转数字
print(f"标签类别: {le.classes_}")
# labels = to_categorical(labels)  # 转one-hot编码
print(labels[:5])
# Out:
# ['./data/slices60/pos/nID_473, ID_622, X_133, Y_259, Z_189(186-211), diam_17, flag_1.npy'
#  './data/slices60/pos/nID_418, ID_548, X_115, Y_286, Z_276(259-342), diam_46, flag_1.npy'
#  './data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_235(228-248), diam_15, flag_1.npy'
#  './data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_245(228-248), diam_15, flag_1.npy'
#  './data/slices60/pos/nID_173, ID_243, X_419, Y_413, Z_264(226-268), diam_37, flag_1.npy']
# 共有10863个npy文件
# 标签类别: ['0' '1']
# [1 1 1 1 1]

# %%
# 打乱顺序
#seed(11)  # 设置random包的随机数种子
imageSets = list(zip(imagePaths, labels))
#shuffle(imageSets)
print(imageSets[:5])
type(imageSets)
imageSets[0][0].split(" ID_")[1].split(",")[0]
# Out:
# [('./data/slices60/pos/nID_473, ID_622, X_133, Y_259, Z_189(186-211), diam_17, flag_1.npy', 1), ('./data/slices60/pos/nID_418, ID_548, X_115, Y_286, Z_276(259-342), diam_46, flag_1.npy', 1), ('./data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_235(228-248), diam_15, flag_1.npy', 1), ('./data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_245(228-248), diam_15, flag_1.npy', 1), ('./data/slices60/pos/nID_173, ID_243, X_419, Y_413, Z_264(226-268), diam_37, flag_1.npy', 1)]
# '622'

# %% [markdown]
# #### 对病人按6：2：2划分训练集、验证集、测试集

# %%
for i in range(len(imageSets)):  # 遍历每张切片提取病人ID、结节nID、结节类型标签flag
    image_path, label = imageSets[i]
    ID = int(image_path.split(" ID_")[1].split(",")[0])
    nID = int(image_path.split("ID_")[1].split(",")[0])
    flag=int(image_path.split("flag_")[1].split(".npy")[0])
    imageSets[i] = (image_path, label, ID,nID,flag)

# %%
df = pd.DataFrame(imageSets, columns=['image_path', 'label', 'ID','nID','flag'])# 构建新数据框df

# %%
IDs = df["ID"].unique().tolist()  # 提取所有病人的ID
len(IDs)
data_list = df.values.tolist()  # df转化为二维列表
data_list[:5]
# Out:
# [['./data/slices60/pos/nID_473, ID_622, X_133, Y_259, Z_189(186-211), diam_17, flag_1.npy',
#   1,
#   622,
#   473,
#   1],
#  ['./data/slices60/pos/nID_418, ID_548, X_115, Y_286, Z_276(259-342), diam_46, flag_1.npy',
#   1,
#   548,
#   418,
#   1],
#  ['./data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_235(228-248), diam_15, flag_1.npy',
#   1,
#   353,
#   256,
#   1],
#  ['./data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_245(228-248), diam_15, flag_1.npy',
#   1,
#   353,
#   256,
#   1],
#  ['./data/slices60/pos/nID_173, ID_243, X_419, Y_413, Z_264(226-268), diam_37, flag_1.npy',
#   1,
#   243,
#   173,
#   1]]

# %%
# 按病人划分训练集和测试集
def psplitDF(data, col_name, reset, test_size=0.2, seed=123, shuffle=True):
    # 全部结节ID列表
    IDs = data[col_name].unique().tolist()
    # 结节ID列表划分为训练集和测试集
    train_IDs, test_IDs = train_test_split(IDs, test_size=test_size, random_state=seed, shuffle=shuffle)
    #X=len(IDs)
    #kf = KFold(n_splits=5,shuffle=False)
    #for train_index , test_index in kf.split(X):
    #    print('train_index:%s , test_index: %s ' %(train_index,test_index))
    # 得到两个数据集
    train_dat = data.loc[data[col_name].isin(train_IDs), ]  # 训练集
    test_dat = data.loc[data[col_name].isin(test_IDs),]  # 测试集
    if reset==True:  # 判断是在划分训练集和测试集，还是在划分训练集和验证集
        train_dat = train_dat.reset_index(drop=True)  # 训练集
        test_dat = test_dat.reset_index(drop=True)  # 测试集
    # 提取索引，用于模型训练
    train_index = train_dat.index.tolist()  # 训练集索引
    test_index = test_dat.index.tolist()  # 测试集索引
    # 返回训练集表、测试集表、训练集表索引、测试集表索引
    return train_dat, test_dat, train_index, test_index

# %%
# 按病人计算各数据子集中0-1分类占比，观察样本平衡性
def pcalRate(data, index):
    # 是否通过索引进行筛选
    if index is None:
        n = data.shape[0]
    else:
        n = len(index)
        data = data.loc[index, ]
    # 结节数量
    nn = len(data["nID"].unique())
    pp=  len(data["ID"].unique())
    rate1 = round(data["flag"].sum() / n * 100, 2)  # 计算数据子集中微乳头切片占比
    rate2 = round(data.groupby("ID")["flag"].mean().mean() * 100, 2)  # 计算数据子集中微乳头结节占比
    return f"切片数: {n}，微乳头切片占比: {rate1}%，结节数: {nn}, 微乳头结节占比：{rate2}%，病人数: {pp}"

# %%
train_dat, test_dat, _, test_index = psplitDF(df, "ID", test_size=0.2, reset=True)  # 按病人ID划分为训练集和测试集
train_datz, valid_dat, train_index, valid_index = psplitDF(train_dat, "ID", test_size=0.25, reset=False)  # 按病人ID将训练集再划分为训练集和验证集
print(len(train_dat["ID"].unique().tolist()))
len(train_dat)
print(f"训练数据中训练集{pcalRate(train_dat, train_index)}")
print(f"训练数据中验证集{pcalRate(valid_dat, valid_index)}")
print(f"测试数据中测试集{pcalRate(test_dat, test_index)}")
# Out:
# 340
# 训练数据中训练集切片数: 6578，微乳头切片占比: 38.81%，结节数: 291, 微乳头结节占比：31.2%，病人数: 255
# 训练数据中验证集切片数: 2278，微乳头切片占比: 34.77%，结节数: 99, 微乳头结节占比：31.0%，病人数: 85
# 测试数据中测试集切片数: 2007，微乳头切片占比: 40.01%，结节数: 93, 微乳头结节占比：28.35%，病人数: 86

# %%
# 数据提取为列表形式
# train_dat.values.tolist() #训练集数据转化为列表
# 从训练集中提取除了前两列（image_path和label）之外的所有列的数据，将其转换为列表
trainSets=train_dat.drop(columns=df.columns[2:]).values.tolist()
# 将训练集的每一行数据转换为元组，并存储在trainSets列表中
trainSets = [tuple(data) for data in trainSets]
testSets=test_dat.drop(columns=df.columns[2:]).values.tolist()
testSets = [tuple(data) for data in testSets]
validSets=valid_dat.drop(columns=df.columns[2:]).values.tolist()
validSets = [tuple(data) for data in validSets]

# %%
# 将数据中的每一行数据转换为元组
for i in range(len(trainSets)):
    trainSets[i] = tuple(trainSets[i])  
type(trainSets)
for i in range(len(testSets)):
    testSets[i] = tuple(testSets[i]) 
for i in range(len(validSets)):
    validSets[i] = tuple(validSets[i])

# %%
trainSets
# Out:
# [('./data/slices60/pos/nID_473, ID_622, X_133, Y_259, Z_189(186-211), diam_17, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_418, ID_548, X_115, Y_286, Z_276(259-342), diam_46, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_235(228-248), diam_15, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_256, ID_353, X_112, Y_271, Z_245(228-248), diam_15, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_173, ID_243, X_419, Y_413, Z_264(226-268), diam_37, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_11, ID_27, X_364, Y_276, Z_110(103-126), diam_12, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_193, ID_272, X_333, Y_157, Z_110(105-142), diam_19, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_481, ID_632, X_293, Y_291, Z_27(15-28), diam_13, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_319, ID_429, X_310, Y_324, Z_220(202-238), diam_29, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_52, ID_90, X_205, Y_246, Z_132(131-174), diam_28, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_168, ID_234, X_320, Y_283, Z_89(60-137), diam_53, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_319, ID_429, X_310, Y_324, Z_235(202-238), diam_29, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_184, ID_257, X_333, Y_357, Z_245(239-263), diam_22, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_77, ID_131, X_121, Y_253, Z_333(310-339), diam_28, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_325, ID_436, X_743, Y_621, Z_97(93-106), diam_19, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_368, ID_485, X_196, Y_364, Z_358(333-375), diam_21, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_418, ID_548, X_115, Y_286, Z_275(259-342), diam_46, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_430, ID_562, X_200, Y_315, Z_53(42-73), diam_23.8, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_164, ID_231, X_122, Y_172, Z_134(123-156), diam_20, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_282, ID_386, X_200, Y_329, Z_113(50-127), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_309, ID_414, X_163, Y_335, Z_58(44-79), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_91, ID_154, X_76, Y_296, Z_318(307-333), diam_21, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_430, ID_562, X_200, Y_315, Z_61(42-73), diam_23.8, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_11, ID_27, X_364, Y_276, Z_104(103-126), diam_12, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_481, ID_632, X_293, Y_291, Z_24(15-28), diam_13, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_168, ID_234, X_320, Y_283, Z_90(60-137), diam_53, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_5, ID_18, X_195, Y_336, Z_215(182-228), diam_33, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_136, ID_201, X_336, Y_375, Z_332(302-339), diam_28, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_168, ID_234, X_320, Y_283, Z_76(60-137), diam_53, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_56, ID_95, X_366, Y_317, Z_272(268-295), diam_21, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_5, ID_18, X_195, Y_336, Z_191(182-228), diam_33, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_250, ID_346, X_309, Y_355, Z_280(228-282), diam_33, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_302, ID_404, X_189, Y_259, Z_127(63-133), diam_42, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_282, ID_386, X_200, Y_329, Z_115(50-127), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_325, ID_436, X_743, Y_621, Z_103(93-106), diam_19, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_173, ID_243, X_419, Y_413, Z_234(226-268), diam_37, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_257, ID_354, X_224, Y_178, Z_164(145-164), diam_17, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_293, ID_398, X_143, Y_326, Z_237(198-243), diam_27.5, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_328, ID_437, X_422, Y_312, Z_146(140-160), diam_20, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_309, ID_414, X_163, Y_335, Z_48(44-79), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_12, ID_29, X_404, Y_290, Z_111(109-114), diam_7, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_168, ID_234, X_320, Y_283, Z_81(60-137), diam_53, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_309, ID_414, X_163, Y_335, Z_62(44-79), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_124, ID_188, X_359, Y_323, Z_281(269-282), diam_15, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_430, ID_562, X_200, Y_315, Z_52(42-73), diam_23.8, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_319, ID_429, X_310, Y_324, Z_206(202-238), diam_29, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_319, ID_429, X_310, Y_324, Z_221(202-238), diam_29, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_353, ID_467, X_385, Y_195, Z_287(265-294), diam_23, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID
flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_418, ID_548, X_115, Y_286, Z_264(259-342), diam_46, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_193, ID_272, X_333, Y_157, Z_140(105-142), diam_19, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_168, ID_234, X_320, Y_283, Z_97(60-137), diam_53, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_173, ID_243, X_419, Y_413, Z_239(226-268), diam_37, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_358, ID_472, X_334, Y_351, Z_377(350-377), diam_16, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_135, ID_201, X_166, Y_382, Z_232(228-280), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_466, ID_614, X_336, Y_235, Z_196(164-199), diam_18, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_98, ID_163, X_208, Y_331, Z_153(138-181), diam_25, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_394, ID_519, X_332, Y_334, Z_47(47-66), diam_22, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_329, ID_438, X_397, Y_285, Z_177(174-190), diam_16.8, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_472, ID_621, X_149, Y_321, Z_148(116-151), diam_26, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_48, ID_84, X_336, Y_355, Z_302(290-307), diam_11, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_98, ID_163, X_208, Y_331, Z_139(138-181), diam_25, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_309, ID_414, X_163, Y_335, Z_61(44-79), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_282, ID_386, X_200, Y_329, Z_118(50-127), diam_32, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_319, ID_429, X_310, Y_324, Z_214(202-238), diam_29, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_261, ID_360, X_133, Y_201, Z_244(233-248), diam_12, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_234, ID_329, X_212, Y_306, Z_45(43-63), diam_12, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_404, ID_530, X_216, Y_315, Z_171(153-171), diam_12.8, flag_1.npy',
#   1),
#  ('./data/slices60/pos/nID_16, ID_32, X_152, Y_281, Z_246(238-259), diam_14, flag_1.npy',
#   1),
#  ...]

# %%
trainset =trainSets+ validSets #将训练集验证集合并
# Out:
# '1'

# %% [markdown]
# #### 构建训练集y_train、测试集y_test和验证集y_valid的标签

# %%
#构建0-1y
y_train=[]
y_test=[]
y_valid=[]
for i in range(6578):
    file_path = trainSets[i][0]  # 获取文件路径
    c = int(file_path.split('flag_')[1].split(".")[0])#提取文件路径中的标签(0或1)并将其附加到列表 y_train
    y_train.append(c)
    
for i in range(2007):
    file_path = testSets[i][0]  # 获取文件路径
    c = int(file_path.split('flag_')[1].split(".")[0])
    y_test.append(c)
    
for i in range(2278):
    file_path = validSets[i][0]  # 获取文件路径
    c = int(file_path.split('flag_')[1].split(".")[0])
    y_valid.append(c)  

#print(y_test)
type(y_test)
y_train=np.array(y_train)
type(y_train)
y_test=np.array(y_test)
type(y_test)
y_test.shape
type(y_valid)
y_valid=np.array(y_valid)
y_valid.shape
# Out:
# (2278,)

# %%
y_train.shape
y_train=list(y_train)
y_train=np.array(y_train)
y_train.resize((6578, 1))#调整y_train数组的形状为(6578, 1)
print(y_train)
y_test=list(y_test)
y_test=np.array(y_test)
y_test.resize((2007, 1))#调整y_test数组的形状为(2007, 1)
y_valid=list(y_valid)
y_valid=np.array(y_valid)
y_valid.resize((2278, 1))#调整y_valid数组的形状为(2278, 1)
# Out:
# [[1]
#  [1]
#  [1]
#  ...
#  [0]
#  [0]
#  [0]]
# (6578, 1)

# %%
#计算训练集中微乳头切片的数量
count=0
for i in range(6578):
    if y_train[i]==1:
        count=count+1
print(count)
# Out:
# 2553

# %%
#计算验证集中微乳头切片的数量
count=0
for i in range(2278):
    if y_valid[i]==1:
        count=count+1
print(count)
# Out:
# 792

# %%
#计算测试集中微乳头切片的数量
count1=0
for i in range(6578):
    if y_train[i]==1:
        count=count+1
print(count)
# Out:
# 3345

# %% [markdown]
# #### 数据预处理（单通道转RGB三通道）

# %%
# 读取单个npy文件
def get_data_from_file(filePath):
    img_gray = np.load(filePath)  # 读取npy，[60,60]
    img_rgb = gray2rgb(img_gray)  # 第一种办法，灰度图转RGB，[60,60,3]
    #img_rgb = np.repeat(img_gray[..., np.newaxis], 1, -1)  # 第二种办法，单通道复制为3通道，[60,60,3]
    #print(tes_image[0].shape)
    #img_rgb=tf.image.resize(img_rgb, [32,32])
    #print(resized)
    return img_rgb

# 遍历列表，读取多个npy文件，组合成一个batch
def combineBatch(paths):
    batch_data = []
    for path in paths:
        batch_data.append(get_data_from_file(path))
    return np.asarray(batch_data)  # [B,H,W,C]

# %%
#从训练集、测试集和验证集的信息中提取出每个样本的文件路径
train_paths = [item[0] for item in trainSets]
len(train_paths)
test_paths = [item[0] for item in testSets]
len(train_paths)
valid_paths = [item[0] for item in validSets]
len(valid_paths)
# Out:
# 2278

# %% [markdown]
# #### 将切片数据分batch输入模型，得到各切片的featuremap，最后可以构成特征矩阵

# %%
#训练集
features1 = []
batchsize = 50  # 每个batch的数据量
N = len(trainSets)  # 样本总数
batchs = N // batchsize  # 分多少个batch计算
for ibatch in trange(batchs):  # 遍历每个整数batch
    batchPaths = train_paths[ibatch * batchsize: (ibatch+1) * batchsize]  # 数据路径切片
    batchData = combineBatch(batchPaths)  # 组合batch数据
    features1.append(batchData)
batchPaths = imagePaths[(ibatch+1) * batchsize: N]  # 数据路径切片
batchData = combineBatch(batchPaths)  # 组合batch数据
features1.append(batchData)  # 存储featuremap
features1 = np.vstack(features1)

features1.shape
# Out:
# 100%|██████████| 131/131 [00:19<00:00,  6.67it/s]
# (6578, 60, 60, 3)

# %%
#测试集
features2 = []
batchsize = 50  # 每个batch的数据量
N = len(testSets)  # 样本总数
batchs = N // batchsize  # 分多少个batch计算
for ibatch in trange(batchs):  # 遍历每个整数batch
    batchPaths = test_paths[ibatch * batchsize: (ibatch+1) * batchsize]  # 数据路径切片
    batchData = combineBatch(batchPaths)  # 组合batch数据
    features2.append(batchData)
batchPaths = imagePaths[(ibatch+1) * batchsize: N]  # 数据路径切片
batchData = combineBatch(batchPaths)  # 组合batch数据
features2.append(batchData)  # 存储featuremap
features2 = np.vstack(features2)

features2.shape
# Out:
# 100%|██████████| 40/40 [00:05<00:00,  7.32it/s]
# (2007, 60, 60, 3)

# %%
#验证集
features3 = []
batchsize = 50  # 每个batch的数据量
N = len(validSets)  # 样本总数
batchs = N // batchsize  # 分多少个batch计算
for ibatch in trange(batchs):  # 遍历每个整数batch
    batchPaths = valid_paths[ibatch * batchsize: (ibatch+1) * batchsize]  # 数据路径切片
    batchData = combineBatch(batchPaths)  # 组合batch数据
    features3.append(batchData)
batchPaths = imagePaths[(ibatch+1) * batchsize: N]  # 数据路径切片
batchData = combineBatch(batchPaths)  # 组合batch数据
features3.append(batchData)  # 存储featuremap
features3 = np.vstack(features3)

features3.shape
# Out:
# 100%|██████████| 45/45 [00:06<00:00,  6.89it/s]
# (2278, 60, 60, 3)

# %% [markdown]
# # 2.DenseNet模型构建

# %%
IMSIZE=60
# 每个dense block中dense layer数目 
nb_layers = 3
# 增长率
growth_rate = 32  
# 输入层
input_layer = Input([IMSIZE,IMSIZE,3])
x = input_layer
# 初始卷积层
x = BatchNormalization()(x)
x = Conv2D(growth_rate*2, (3,3), padding='same', activation='relu')(x)
# 设置 [Dense Block + Transition Block] 多个，此处以1个为例
for j in range(3):
    # 1.Dense Block
    # 用一个列表存放提供特征的层
    feature_list = [x]
    for i in range(nb_layers):   
        x = BatchNormalization()(x)
        x = Conv2D(growth_rate, (3, 3), padding="same", activation='relu')(x)   
        feature_list.append(x)
        if i<(nb_layers-1):
            x = Concatenate()(feature_list)
        
    
    # 2.Transition Block
    x = BatchNormalization()(x)
    x = Conv2D(growth_rate, (1, 1), padding="same", activation='relu')(x)
    x = AveragePooling2D((2, 2), strides=(2, 2))(x)
    

    
feature_list = [x]
for i in range(nb_layers):            
    x = Conv2D(growth_rate, (3, 3), padding="same", activation='relu')(x)   
    feature_list.append(x)
    if i<(nb_layers-1):
        x = Concatenate()(feature_list)

# 全局池化
x = GlobalAveragePooling2D()(x)
x = Dense(1,activation='sigmoid')(x)
output_layer = x
model = Model(input_layer,output_layer)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60, 60, 3)]  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 60, 60, 3)    12          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 60, 60, 64)   1792        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 60, 60, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 60, 60, 32)   18464       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 60, 60, 96)   0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 60, 60, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 60, 60, 32)   27680       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 60, 128)  0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 60, 60, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 60, 60, 32)   36896       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 60, 60, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 60, 60, 32)   1056        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 30, 30, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 30, 30, 32)   128         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 30, 30, 32)   9248        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 30, 30, 64)   0           average_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 30, 30, 64)   256         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 30, 30, 32)   18464       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 30, 30, 96)   0           average_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 30, 30, 96)   384         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 30, 32)   27680       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 30, 30, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 30, 30, 32)   1056        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 15, 15, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 15, 15, 32)   128         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 15, 32)   9248        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 15, 15, 64)   0           average_pooling2d_1[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 15, 15, 64)   256         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 15, 15, 32)   18464       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 15, 15, 96)   0           average_pooling2d_1[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 15, 15, 96)   384         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 15, 15, 32)   27680       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 15, 15, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 15, 15, 32)   1056        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 7, 32)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 32)     9248        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 64)     0           average_pooling2d_2[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 32)     18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 96)     0           average_pooling2d_2[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 32)     27680       concatenate_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            33          global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 257,293
# Trainable params: 255,751
# Non-trainable params: 1,542
# __________________________________________________________________________________________________

# %% [markdown]
# #### 模型编译与训练

# %%
# 记录训练开始时间，同时作为保存模型文件名的前缀
train_start = time.strftime("%Y-%m-%d %H:%M:%S")
# 初始学习率为0.001，如果20个epoch后精度没有提升，学习率降低0.5；存外样本精度最高的模型
model_file = os.path.join(model_path, f'{train_start} res_bestden.h5')
logging_file = os.path.join(model_path, f"{train_start} res_metricden.csv")
callback = get_callbacks(model_file, initial_learning_rate=0.01, learning_rate_drop=0.5, learning_rate_epochs=None,
                  learning_rate_patience=20, logging_file=logging_file, verbosity=1,
                  early_stopping_patience=None,tensorboard_callback = None)
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=[keras.metrics.BinaryAccuracy()])
# 训练模型
model.fit(features1, y_train,epochs=30, callbacks=callback, validation_data=(features3, y_valid),
           workers=16,use_multiprocessing=True)
#cbamuse_multiprocessing=True
# Out:
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/keras/backend.py:4993: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   warnings.warn(
# Train on 6578 samples, validate on 2278 samples
# Epoch 1/30
# 6578/6578 [==============================] - ETA: 0s - loss: 0.5595 - binary_accuracy: 0.7165
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6578/6578 [==============================] - 11s 2ms/sample - loss: 0.5595 - binary_accuracy: 0.7165 - val_loss: 0.6725 - val_binary_accuracy: 0.6216 - lr: 0.0010
# Epoch 2/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.4726 - binary_accuracy: 0.7771 - val_loss: 1.4033 - val_binary_accuracy: 0.6624 - lr: 0.0010
# Epoch 3/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.4197 - binary_accuracy: 0.8080 - val_loss: 0.6415 - val_binary_accuracy: 0.6602 - lr: 0.0010
# Epoch 4/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.3503 - binary_accuracy: 0.8457 - val_loss: 0.7087 - val_binary_accuracy: 0.6541 - lr: 0.0010
# Epoch 5/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.2856 - binary_accuracy: 0.8799 - val_loss: 0.5928 - val_binary_accuracy: 0.7103 - lr: 0.0010
# Epoch 6/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.2247 - binary_accuracy: 0.9118 - val_loss: 0.8346 - val_binary_accuracy: 0.7024 - lr: 0.0010
# Epoch 7/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.1660 - binary_accuracy: 0.9371 - val_loss: 1.1598 - val_binary_accuracy: 0.6936 - lr: 0.0010
# Epoch 8/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.1282 - binary_accuracy: 0.9483 - val_loss: 0.9690 - val_binary_accuracy: 0.7076 - lr: 0.0010
# Epoch 9/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.1030 - binary_accuracy: 0.9635 - val_loss: 1.3223 - val_binary_accuracy: 0.6690 - lr: 0.0010
# Epoch 10/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0835 - binary_accuracy: 0.9694 - val_loss: 1.7997 - val_binary_accuracy: 0.7199 - lr: 0.0010
# Epoch 11/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0765 - binary_accuracy: 0.9735 - val_loss: 1.3933 - val_binary_accuracy: 0.6668 - lr: 0.0010
# Epoch 12/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0610 - binary_accuracy: 0.9786 - val_loss: 1.8981 - val_binary_accuracy: 0.6545 - lr: 0.0010
# Epoch 13/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0467 - binary_accuracy: 0.9833 - val_loss: 1.9467 - val_binary_accuracy: 0.6405 - lr: 0.0010
# Epoch 14/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0576 - binary_accuracy: 0.9807 - val_loss: 1.5577 - val_binary_accuracy: 0.7129 - lr: 0.0010
# Epoch 15/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0367 - binary_accuracy: 0.9883 - val_loss: 1.6238 - val_binary_accuracy: 0.6993 - lr: 0.0010
# Epoch 16/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0389 - binary_accuracy: 0.9863 - val_loss: 1.9576 - val_binary_accuracy: 0.7252 - lr: 0.0010
# Epoch 17/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0281 - binary_accuracy: 0.9904 - val_loss: 1.9248 - val_binary_accuracy: 0.6475 - lr: 0.0010
# Epoch 18/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0295 - binary_accuracy: 0.9900 - val_loss: 1.9571 - val_binary_accuracy: 0.7019 - lr: 0.0010
# Epoch 19/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0075 - binary_accuracy: 0.9976 - val_loss: 2.4823 - val_binary_accuracy: 0.6980 - lr: 0.0010
# Epoch 20/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0555 - binary_accuracy: 0.9813 - val_loss: 1.6296 - val_binary_accuracy: 0.6699 - lr: 0.0010
# Epoch 21/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0163 - binary_accuracy: 0.9939 - val_loss: 3.0571 - val_binary_accuracy: 0.6466 - lr: 0.0010
# Epoch 22/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0453 - binary_accuracy: 0.9840 - val_loss: 2.1948 - val_binary_accuracy: 0.7050 - lr: 0.0010
# Epoch 23/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0118 - binary_accuracy: 0.9959 - val_loss: 2.3979 - val_binary_accuracy: 0.6861 - lr: 0.0010
# Epoch 24/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0316 - binary_accuracy: 0.9874 - val_loss: 1.8590 - val_binary_accuracy: 0.6853 - lr: 0.0010
# Epoch 25/30
# 6560/6578 [============================>.] - ETA: 0s - loss: 0.0271 - binary_accuracy: 0.9915
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0271 - binary_accuracy: 0.9915 - val_loss: 2.1615 - val_binary_accuracy: 0.7081 - lr: 0.0010
# Epoch 26/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0050 - binary_accuracy: 0.9982 - val_loss: 2.2321 - val_binary_accuracy: 0.6752 - lr: 5.0000e-04
# Epoch 27/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0041 - binary_accuracy: 0.9986 - val_loss: 2.1613 - val_binary_accuracy: 0.6787 - lr: 5.0000e-04
# Epoch 28/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0013 - binary_accuracy: 0.9998 - val_loss: 2.2466 - val_binary_accuracy: 0.6962 - lr: 5.0000e-04
# Epoch 29/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 9.9008e-04 - binary_accuracy: 1.0000 - val_loss: 2.4426 - val_binary_accuracy: 0.7112 - lr: 5.0000e-04
# Epoch 30/30
# 6578/6578 [==============================] - 8s 1ms/sample - loss: 0.0033 - binary_accuracy: 0.9989 - val_loss: 2.4857 - val_binary_accuracy: 0.6734 - lr: 5.0000e-04

# %% [markdown]
# #### 模型预测

# %%
result=model.predict(features2) #对测试集进行预测
#pred = tf.argmax(result, axis=1)
print(result)
# Out:
# [[9.9999833e-01]
#  [1.0165333e-05]
#  [8.5038823e-01]
#  ...
#  [1.4127749e-05]
#  [9.2208251e-02]
#  [9.9997330e-01]]

# %%
#计算阈值，将预测结果转换为0或1
result.max()
result.min()
result.shape
a=result.min()+(result.max()-result.min())/2
result1=result.tolist() # 将预测结果转换为列表
type(result.tolist())
pred1={}
for i in range(2007):
    if result1[i]<=a:
        pred1[i]=0
    else:
        pred1[i]=1
# Out:
# (2007, 1)

# %%
#统计预测结果为1（微乳头）的数量
count=0
for i in range(2007):
    if pred1[i]==1:
        count=count+1
print(count)
# Out:
# 678

# %%
# 提取预测结果
#pred1=pred1.numpy()
pred1 = pred1.items()
# Convert object to a list
pred1= list(pred1) 
# Convert list to an array
pred1 = np.array(pred1) 
# print the numpy array
print(type(pred1))
#type(y_test)
print(type(result))
pred=pred1[:,1]
pred
# Out:
# <class 'numpy.ndarray'>
# array([1, 0, 1, ..., 0, 0, 1])

# %% [markdown]
# # 3.模型评估

# %%
#切片层面
labels_value = np.array([0, 1])
tn, fp, fn, tp = confusion_matrix(y_test, pred, labels=labels_value).ravel() ##ravel数组维度拉成一维数组
    # Accuracy
acc1 = accuracy_score(y_test, pred)
#     print("Accuracy:{:.4f}".format(acc1))
    # 特异性：TN / N
specificity = tn / (tn+fp)
    # 敏感度：TP / P
sensitivity= tp/(tp+fn)
    # Positive predictive value PPV = TP / (TP + FP)
ppv = tp / (tp+fp)
    # Negative predictive value NPV = TN / (TN + FN)
npv = tn / (tn+fn)
    # F1-score
f1 = f1_score(y_test, pred) ##结果是类别1的score
acc2 = accuracy_score(y_test, pred)
    # ROC曲线
fpr, tpr, thresholds = roc_curve(y_test, result[:])
roc_auc = auc(fpr, tpr)
    # 最佳阈值
i = np.arange(len(tpr)) # index for df
roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(thresholds, index = i)})
bestThresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]] ##argsort数组中的元素从小到大排序后的索引数组值
title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
cm = confusion_matrix(y_test, pred)
    # Only use the labels that appear in the data
classes = labels_value[unique_labels(y_test, pred)]
print('Confusion matrix, without normalization')
print(cm)

#     fig, ax = plt.subplots()
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(121)
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,
        title=title,
        ylabel='True label',
        xlabel='Predicted label')

ax.set_ylim(len(classes)-0.5, -0.5)

    # Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=0, ha="right",
             rotation_mode="anchor")  
    # Loop over data dimensions and create text annotations.
fmt = 'd' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")
    
    # 绘制ROC曲线
ax = fig.add_subplot(122)
ax.plot(fpr, tpr, label='ROC')
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')
    
    # 整合评估指标
metrics_s = pd.DataFrame({"ACC_pred": [acc1], "Specificity": [specificity], "Sensitivity": [sensitivity],
                            "PPV": [ppv], "NPV": [npv], "F1-Score": [f1], "ACC_argmax": [acc2], "AUC": [roc_auc]})
    
fig.tight_layout()
metrics_s
# Out:
# Confusion matrix, without normalization
# [[955 249]
#  [374 429]]
#    ACC_pred  Specificity  Sensitivity       PPV       NPV  F1-Score  \
# 0  0.689586     0.793189     0.534247  0.632743  0.718585  0.579338
#
#    ACC_argmax       AUC
# 0    0.689586  0.730318

# %%
#计算结节层面的预测结果
pthresh=0.5
if test_index is None:
    noduleData = test_dat.loc[:, ["nID", "ID", "flag"]].copy()  # copy测试集原数据
else:
    noduleData = test_dat.loc[test_index, ["nID", "ID", "flag"]].copy()  # 复制测试集指定索引的数据
noduleData["y_pred"] = pred
noduleData["0_value"] = result
noduleData = noduleData.groupby("nID").mean()  # 平均法
noduleData[["ID","flag"]] = noduleData[["ID", "flag"]].astype(int)  # 保持数据类型
noduleData["voting_pred"] = noduleData["y_pred"].apply(lambda x: 1 if x > pthresh else 0)  # 投票法得到预测标签，90%阈值
#compreEval(noduleData["flag"], noduleData["voting_pred"], np.asarray(noduleData["0_value"]), classes=labels_value, normalize=False)

# %%
# 结节层面
tn, fp, fn, tp = confusion_matrix(noduleData["flag"], noduleData["voting_pred"], labels=labels_value).ravel() ##ravel数组维度拉成一维数组
    # Accuracy
acc1 = accuracy_score(noduleData["flag"], noduleData["voting_pred"])
#     print("Accuracy:{:.4f}".format(acc1))
    # 特异性：TN / N
specificity = tn / (tn+fp)
    # 敏感度：TP / P
sensitivity= tp/(tp+fn)
    # Positive predictive value PPV = TP / (TP + FP)
ppv = tp / (tp+fp)
    # Negative predictive value NPV = TN / (TN + FN)
npv = tn / (tn+fn)
    # F1-score
f1 = f1_score(noduleData["flag"], noduleData["voting_pred"]) ##结果是类别1的score
acc2 = accuracy_score(noduleData["flag"], noduleData["voting_pred"])
    # ROC曲线
fpr, tpr, thresholds = roc_curve(noduleData["flag"], np.asarray(noduleData["0_value"]))
roc_auc = auc(fpr, tpr)
    # 最佳阈值
i = np.arange(len(tpr)) # index for df
roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(thresholds, index = i)})
bestThresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]] ##argsort数组中的元素从小到大排序后的索引数组值
title = 'Confusion matrix, without normalization'
    # Compute confusion matrix
cm = confusion_matrix(noduleData["flag"], noduleData["voting_pred"])
    # Only use the labels that appear in the data
classes = labels_value[unique_labels(noduleData["flag"], noduleData["voting_pred"])]
print('Confusion matrix, without normalization')
print(cm)
#     fig, ax = plt.subplots()
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(121)
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,
        title=title,
        ylabel='True label',
        xlabel='Predicted label')
ax.set_ylim(len(classes)-0.5, -0.5)
    # Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=0, ha="right",
             rotation_mode="anchor")  
    # Loop over data dimensions and create text annotations.
fmt = 'd' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")
    # 绘制ROC曲线
ax = fig.add_subplot(122)
ax.plot(fpr, tpr, label='ROC')
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')
    # 整合评估指标
metrics_n = pd.DataFrame({"ACC_pred": [acc1], "Specificity": [specificity], "Sensitivity": [sensitivity],
                            "PPV": [ppv], "NPV": [npv], "F1-Score": [f1], "ACC_argmax": [acc2], "AUC": [roc_auc]})
fig.tight_layout()
metrics_n
# Out:
# Confusion matrix, without normalization
# [[48 19]
#  [ 9 17]]
#    ACC_pred  Specificity  Sensitivity       PPV       NPV  F1-Score  \
# 0  0.698925     0.716418     0.653846  0.472222  0.842105  0.548387
#
#    ACC_argmax       AUC
# 0    0.698925  0.730769
